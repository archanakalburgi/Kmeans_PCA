# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/vmware/RCA_CBO_anonamized_filter_2.csv")

# %%
df.head()
# Out:
#           day  sum(lineitem_unblendedcost)  sum(lineitem_usageamount)  \
# 0  2022-03-02                 1.360000e-08               6.798000e-07
# 1  2022-01-30                 5.200000e-09               2.552000e-07
# 2  2022-02-02                 1.232000e-05               2.800000e+01
# 3  2022-01-18                 6.840000e-04               1.710000e+03
# 4  2021-12-22                 5.200000e-09               2.552000e-07
#
#    sum(lineitem_blendedcost)  sum(pricing_publicondemandcost)  \
# 0               1.360000e-08                     1.360000e-08
# 1               5.200000e-09                     5.200000e-09
# 2               1.232000e-05                     1.232000e-05
# 3               6.840000e-04                     6.840000e-04
# 4               5.200000e-09                     5.200000e-09
#
#    sum(reservation_effectivecost)  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# ...

# %%
text = df['lineitem_lineitemdescription']

# %%
type(text)
# Out:
# pandas.core.series.Series

# %%
text
# Out:
# 0         $0.02 per GB - US East (Northern Virginia) dat...
# 1         $0.02 per GB - EU (Ireland) data transfer to C...
# 2             $0.0044 per 10,000 GET and all other requests
# 3              $0.004 per 10,000 GET and all other requests
# 4         $0.02 per GB - US East (Ohio) data transfer to...
#                                 ...
# 819231    $0.09 per GB - Asia Pacific (Singapore) data t...
# 819232         $0.004 per 10,000 GET and all other requests
# 819233    $0.02 per GB - US East (Northern Virginia) dat...
# 819234    $0.005 per 1,000 PUT, COPY, POST, or LIST requ...
# 819235    $0.050 per GB - greater than 150 TB / month da...
# Name: lineitem_lineitemdescription, Length: 819236, dtype: object

# %%
text_corp = []
for tt in text:
  tt_aaay = tt.split()
  text_corp.append(tt_aaay)

# %%
text_crop = df['lineitem_lineitemdescription'].values.tolist()

# %%
text_crop
